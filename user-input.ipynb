# %% [markdown]
# Software 2 types -
#
# static software : Unidirectional conversation between user and software
#
# dynamic software : software and user are taking with each other
#
# for dynamic software user input is required

# %%
input(prompt = "Apna naam bata : ")
# Out:
# 'yash'

# %% [markdown]
# user jab input func se input deta hain tab user k pass always string format mai values jata hai

# %%
first_num = input("Enter the first number : ")
second_num = input("Enter the second number : ")

# %%
print(first_num + second_num)
# Out:
# 34

# %%
# type
print(type(first_num))
# Out:
# <class 'str'>

# %%
first_num
# Out:
# '3'

# %% [markdown]
# Type Conversion
#
# implicit : automatic type conversion
#
# explicit : user will tell to type conversion

# %%
4 + 5.6  # implicit
# Out:
# 9.6

# %%
first_num + second_num   # in this type of case explicit type conversion is required
# Out:
# '34'

# %%
int('45')
# Out:
# 45

# %%
float(2)
# Out:
# 2.0

# %%
str(5)
# Out:
# '5'

# %%
bool(1)
# Out:
# True

# %%
complex(3)
# Out:
# (3+0j)

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
int('kolkata')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int('kolkata')
#
# ValueError: invalid literal for int() with base 10: 'kolkata'

# %% [markdown]
# in java type casting is permanent operation but in python type conversion is not a permanent operation

# %%
a = 4.5

# %%
int(a)
# Out:
# 4

# %%
a
# Out:
# 4.5

# %%
first_num = input("Enter the first number : ")
second_num = input("Enter the second number : ")

result = int(first_num) + int(second_num)
print(result)
# Out:
# 7
