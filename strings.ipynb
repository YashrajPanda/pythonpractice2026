# %% [markdown]
# Strings
#
# Strings are sequence of characters...
#
# In python specifically, strings are sequence of Unicode Characters ...
#
# - Creating String
#
# - Accessing Strings
#
# - Adding chars to strings
#
# - Editing Strings
#
# - Deleting Strings
#
# - Operations on Strings
#
# - String Functions

# %%
# creating
c = 'Hello'
print(c)
# Out:
# Hello

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
"It's a rainy day"
# Out:
# "It's a rainy day"

# %%
c = '''Hello
World'''
# multiline string
print(c)
# Out:
# Hello
# World

# %%
c = """Hello
World"""
print(c)
# Out:
# Hello
# World

# %% [markdown]
# Accessing substring from a string

# %%
# Concept of Indexing
s = "Hello"
print(s[0])  # H
print(s[1])  # e
# Out:
# H
# e

# %%
# Types of Indexing:
# 1. Positive Indexing
print(s[0])  # H
print(s[1])  # e

# 2. Negative Indexing
print(s[-1])  # o
print(s[-2])  # l
# Out:
# H
# e
# o
# l

# %% [markdown]
# Slicing

# %%
c = "Hello World"

print(c[0:5])  # Hello
print(c[6:])   # World
# Out:
# Hello
# World

# %%
print(c[2:])
# Out:
# llo World

# %%
print(c[:5])   # Hello
# Out:
# Hello

# %%
print(c[:])
# Out:
# Hello World

# %%
print(c[2:7:2])
# Out:
# loW

# %%
print(c[-5:-1:2])
# Out:
# Wr

# %%
print(c[::-1])  # Reverse the string
# Out:
# dlroW olleH

# %% [markdown]
# Editing and Deleting in python

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c[0]= 'h'  # This will raise an error because strings are immutable (not changeable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 c[0]= 'h'  # This will raise an error because strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
# Deletion of string
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
del c[0]  # This will raise an error because we cannot delete a part of the string, we can only delete the whole string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 del c[0]  # This will raise an error because we cannot delete a part of the string, we can only delete the whole string
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# Operationsnon string
#
# - Arithmetic Operator
#
# - Relational Operator
#
# - Logical Operator
#
# - Loops on Strings
#
# - Membership Operations
