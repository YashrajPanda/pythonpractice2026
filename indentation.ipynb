# %%
if(x == "xyz"){
    line 1; # the space before line 1 is called indentation. in c the space before line 1 is not important but in python it is important
}else(
    line 2;
)

# %%
name = "ty"
if name == "xyz":
    print("line 1") # the space before print is called indentation
else:
    print("line 2")
# Out:
# line 2
