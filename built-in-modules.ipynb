# %% [markdown]
# What are modules ?
#
# Consider a module to be the same as a code library.
#
# A file containing a set of functions you want to include in your application.
#
# Examples of python modules
#
# 1. Math
#
# 2. Random
#
# 3. OS
#
# 4. time

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# c:\Users\Yashraj2005\anaconda3\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
#
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\spacepy\time.py:2448: UserWarning:
#
# Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#
# c:\Users\Yashraj2005\anaconda3\Lib\site-packages\spacepy\empiricals.py:26: UserWarning:
#
# Qin-Denton/OMNI2 data not found in current format. This module has limited functionality. Run spacepy.toolbox.update(QDomni=True) to download data.
#
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# 3204bda914b7f2c6f497__mypyc click               markdown            six
# IPython             cloudpickle         markdown_it         skimage
# OpenSSL             cmath               markupsafe          sklearn
# PIL                 cmd                 marshal             slugify
# PyQt5               code                math                smart_open
# __future__          codecs              matplotlib          smmap
# __hello__           codeop              matplotlib_inline   smtplib
# __phello__          collections         mccabe              sndhdr
# _abc                colorama            mdit_py_plugins     sniffio
# _aix_support        colorcet            mdurl               snowballstemmer
# _argon2_cffi_bindings colorsys            menuinst            socket
# _ast                comm                mimetypes           socketserver
# _asyncio            commctrl            mistune             socks
# _bisect             compileall          mkl                 sockshandler
# _black_version      concurrent          mkl_fft             sortedcontainers
# _blake2             conda               mkl_random          soupsieve
# _brotli             conda_build         ml_dtypes           spacepy
# _bz2                conda_content_trust mmap                sphinx
# _cffi_backend       conda_env           mmapfile            spyder
# _codecs             conda_index         mmsystem            spyder_kernels
# _codecs_cn          conda_libmamba_solver modulefinder        sqlalchemy
# _codecs_hk          conda_pack          more_itertools      sqlite3
# _codecs_iso2022     conda_package_handling mpmath              sre_compile
# _codecs_jp          conda_package_streaming msgpack             sre_constants
# _codecs_kr          conda_token         msilib              sre_parse
# _codecs_tw          configparser        msvcrt              ssl
# _collections        constantly          multidict           sspi
# _collections_abc    contextlib          multipledispatch    sspicon
# _compat_pickle      contextvars         multiprocessing     stack_data
# _compression        contourpy           mypy                start_pythonwin
# _contextvars        cookiecutter        mypy_extensions     stat
# _csv                copy                mypyc               statistics
# _ctypes             copyreg             nacl                statsmodels
# _ctypes_test        cpuinfo             namex               streamlit
# _datetime           crypt               navigator_updater   string
# _decimal            cryptography        nb_conda_kernels    stringprep
# _distutils_hack     cssselect           nbclient            struct
# _elementtree        csv                 nbconvert           subprocess
# _functools          ctypes              nbformat            sunau
# _hashlib            curl                nest_asyncio        sympy
# _heapq              curses              netCDF4             symtable
# _imp                cwp                 netbios             sys
# _io                 cycler              netrc               sysconfig
# _json               cytoolz             networkx            tables
# _locale             dask                nltk                tabnanny
# _lsprof             dask_expr           nntplib             tabulate
# _lzma               dataclasses         nose                tarfile
# _markupbase         datashader          notebook            tblib
# _md5                datetime            notebook_shim       telnetlib
# _msi                dateutil            nt                  tempfile
# _multibytecodec     dbi                 ntpath              tenacity
# _multiprocessing    dbm                 ntsecuritycon       tensorboard
# _nsis               dde                 nturl2path          tensorboard_data_server
# _opcode             debugpy             numba               tensorflow
# _operator           decimal             numbergen           termcolor
# _osx_support        decorator           numbers             terminado
# _overlapped         defusedxml          numexpr             test
# _pickle             diff_match_patch    numpy               test_pycosat
# _plotly_future_     difflib             numpydoc            text_unidecode
# _plotly_utils       dill                odbc                textdistance
# _py_abc             dis                 opcode              textwrap
# _pydatetime         distributed         openpyxl            this
# _pydecimal          distro              operator            threading
# _pyio               docstring_to_markdown opt_einsum          threadpoolctl
# _pylong             doctest             optparse            three_merge
# _pytest             docutils            optree              tifffile
# _queue              dotenv              os                  time
# _random             email               overrides           timeit
# _ruamel_yaml        encodings           packaging           timer
# _sha1               ensurepip           pandas              tinycss2
# _sha2               enum                pandocfilters       tkinter
# _sha3               erfa                panel               tldextract
# _signal             errno               param               tlz
# _sitebuiltins       et_xmlfile          paramiko            token
# _socket             executing           parsel              tokenize
# _sqlite3            fastjsonschema      parso               toml
# _sre                faulthandler        partd               tomli
# _ssl                filecmp             pasta               tomlkit
# _stat               fileinput           pathlib             tomllib
# _statistics         filelock            pathspec            toolz
# _string             flake8              patsy               tornado
# _strptime           flask               pdb                 tqdm
# _struct             flatbuffers         perfmon             trace
# _symtable           fnmatch             pexpect             traceback
# _system_path        fontTools           pickle              tracemalloc
# _testbuffer         fractions           pickleshare         traitlets
# _testcapi           frozendict          pickletools         truststore
# _testclinic         frozenlist          pip                 tty
# _testconsole        fsspec              pipes               turtle
# _testimportmultiple ftplib              pkce                turtledemo
# _testinternalcapi   functools           pkg_resources       twisted
# _testmultiphase     gast                pkginfo             typeguard
# _testsinglephase    gc                  pkgutil             types
# _thread             genericpath         platform            typing
# _threading_local    gensim              platformdirs        typing_extensions
# _tkinter            getopt              plistlib            tzdata
# _tokenize           getpass             plotly              uc_micro
# _tracemalloc        gettext             pluggy              ujson
# _typing             git                 ply                 unicodedata
# _uuid               gitdb               poplib              unicodedata2
# _warnings           glob                posixpath           unidecode
# _weakref            graphlib            pprint              unittest
# _weakrefset         greenlet            profile             urllib
# _win32sysloader     grpc                prometheus_client   urllib3
# _win32verstamp_pywin32ctypes gzip                prompt_toolkit      uu
# _winapi             h11                 protego             uuid
# _winxptheme         h5py                pstats              venv
# _wmi                hashlib             psutil              w3lib
# _xxinterpchannels   heapdict            pty                 warnings
# _xxsubinterpreters  heapq               ptyprocess          watchdog
# _yaml               hmac                pure_eval           wave
# _zoneinfo           holoviews           py                  wcwidth
# abc                 html                py_compile          weakref
# absl                http                pyarrow             webbrowser
# adodbapi            httpcore            pyasn1              webencodings
# aext_assistant      httpx               pyasn1_modules      websocket
# aext_assistant_server hvplot              pyclbr              werkzeug
# aext_core           hyperlink           pycodestyle         whatthepatch
# aext_core_server    idlelib             pycosat             wheel
# aext_panels         idna                pycparser           widgetsnbextension
# aext_panels_server  imagecodecs         pyct                win2kras
# aext_share_notebook imageio             pycurl              win32api
# aext_share_notebook_server imagesize           pydantic            win32clipboard
# aext_shared         imaplib             pydantic_core       win32com
# aext_toolbox        imblearn            pydeck              win32con
# afxres              imghdr              pydispatch          win32console
# aifc                importlib           pydoc               win32cred
# aiobotocore         importlib_metadata  pydoc_data          win32crypt
# aiohappyeyeballs    importlib_resources pydocstyle          win32cryptcon
# aiohttp             incremental         pyexpat             win32ctypes
# aioitertools        inflect             pyflakes            win32event
# aiosignal           inflection          pygments            win32evtlog
# alabaster           iniconfig           pylab               win32evtlogutil
# alembic             inspect             pylint              win32file
# altair              intake              pylint_venv         win32gui
# anaconda_anon_usage intervaltree        pyls_spyder         win32gui_struct
# anaconda_catalogs   io                  pylsp               win32help
# anaconda_cloud_auth ipaddress           pylsp_black         win32inet
# anaconda_navigator  ipykernel           pylsp_jsonrpc       win32inetcon
# anaconda_project    ipykernel_launcher  pyodbc              win32job
# annotated_types     ipython_genutils    pyparsing           win32lz
# antigravity         ipython_pygments_lexers pytest              win32net
# anyio               ipywidgets          pythoncom           win32netcon
# api                 isapi               pythonjsonlogger    win32pdh
# appdirs             isort               pytoolconfig        win32pdhquery
# archspec            isympy              pytz                win32pdhutil
# argon2              itemadapter         pyviz_comms         win32pipe
# argparse            itemloaders         pywin               win32print
# array               itertools           pywin32_bootstrap   win32process
# arrow               itsdangerous        pywin32_testutil    win32profile
# ast                 jedi                pywintypes          win32ras
# astroid             jellyfish           pywt                win32rcparser
# astropy             jinja2              qdarkstyle          win32security
# astropy_iers_data   jmespath            qstylizer           win32service
# asttokens           joblib              qtawesome           win32serviceutil
# astunparse          json                qtconsole           win32timezone
# async_lru           json5               qtpy                win32trace
# asyncio             jsonpatch           queue               win32traceutil
# atexit              jsonpointer         queuelib            win32transaction
# atomicwrites        jsonschema          quopri              win32ts
# attr                jsonschema_specifications random              win32ui
# attrs               jupyter             rasutil             win32uiole
# audioop             jupyter_client      re                  win32verstamp
# autocommand         jupyter_console     referencing         win32wnet
# automat             jupyter_core        regcheck            win_inet_pton
# autopep8            jupyter_events      regex               winerror
# babel               jupyter_lsp         regutil             winioctlcon
# backports           jupyter_server      repo_cli            winnt
# base64              jupyter_server_terminals reprlib             winperf
# bcrypt              jupyterlab          requests            winpty
# bdb                 jupyterlab_plotly   requests_file       winreg
# binaryornot         jupyterlab_pygments requests_toolbelt   winsound
# binascii            jupyterlab_server   rfc3339_validator   winxpgui
# binstar_client      jupyterlab_widgets  rfc3986_validator   winxptheme
# bisect              jwt                 rich                wrapt
# black               kaggle              rlcompleter         wsgiref
# blackd              kagglesdk           rope                xarray
# bleach              keras               rpds                xdrlib
# blib2to3            keyring             rtree               xlwings
# blinker             keyword             ruamel_yaml         xlwingsjs
# bokeh               kiwisolver          runpy               xml
# boltons             lazy_loader         s3fs                xmlrpc
# botocore            lazy_object_proxy   sched               xxlimited
# bottleneck          lckr_jupyterlab_variableinspector scipy               xxlimited_35
# brotli              lib2to3             scrapy              xxsubtype
# bs4                 libarchive          seaborn             xyzservices
# builtins            libmambapy          secrets             yaml
# bz2                 lief                select              yapf
# cProfile            linecache           selectors           yapf_third_party
# cachetools          linkify_it          semver              yapftests
# calendar            llvmlite            send2trash          yarl
# cdflib              lmdb                sentry_sdk          zict
# certifi             locale              service_identity    zipapp
# cffi                locket              servicemanager      zipfile
# cftime              logging             setuptools          zipimport
# cgi                 lxml                shelve              zipp
# cgitb               lz4                 shlex               zlib
# chardet             lzma                shutil              zmq
# charset_normalizer  mailbox             signal              zoneinfo
# chunk               mailcap             sipbuild            zope
# clang               mako                site                zstandard
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# include <stdio.h>
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(3.14)
# Out:
# 4

# %%
math.floor(3.14)
# Out:
# 3

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import random
random.randint(1, 10)
# Out:
# 3

# %%
a = ([1, 2, 3, 4, 5])
random.shuffle(a)
print(a)
# Out:
# [4, 3, 5, 2, 1]

# %%
import time
time.time()
# Out:
# 1771742983.8625462

# %%
time.ctime()
# Out:
# 'Sun Feb 22 12:20:10 2026'

# %%
print("Hello")
time.sleep(1)
print("World")
time.sleep(1)
print("Welcome to Python programming")
# Out:
# Hello
# World
# Welcome to Python programming
