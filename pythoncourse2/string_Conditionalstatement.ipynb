# %% [markdown]
# Strings :
#
# string is a data type that store a sequence of character.
#
# Basic Operations :
#
# - Concatenation
#
# - length of str

# %%
str1 = "Hello"
str2 = "world"
result = str1 + " " + str2
print(result)
len(str1)
# Out:
# Hello world
# 5

# %% [markdown]
# Indexing :

# %%
str = "Hello World"
# str[4] = "@" # do not manulate string as it is immutable
print(str[0]) # H
# Out:
# H

# %% [markdown]
# Slicing

# %%
str = "hello world"
print(str[:4])
# Out:
# hell

# %% [markdown]
# String Functions

# %%
str = "i am yashraj panda"
print(str.endswith("nda"))
str = str.capitalize()
print(str)
# Out:
# True
# I am yashraj panda

# %%
print(str.replace("I", "a"))
# Out:
# a am yashraj panda

# %%
print(str.find("yashraj"))
# Out:
# 5

# %% [markdown]
# nested if

# %%
age = 21

if (age >= 18):
    if(age >= 80):
        print("cannot drive !")
    else:
        print("can drive !")
        
else:
    print("cannot drive ")
# Out:
# can drive !
