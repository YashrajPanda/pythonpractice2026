# %%
import random
random.randint(1, 100)
# Out:
# 8

# %%
jackpot = random.randint(1, 100)
guess = int(input("Enter your guess: "))
counter = 1

while guess != jackpot:
    if guess < jackpot:
        print("Guess higher number")
    else:
        print("Guess lower number")
    guess = int(input("Enter your guess: "))
    counter += 1
    
print("Sahi guess kiya")
print(f"Apne {counter} attempts me guess kiya")
# Out:
# Guess higher number
# Guess higher number
# Guess higher number
# Guess higher number
# Sahi guess kiya
# Apne 5 attempts me guess kiya
