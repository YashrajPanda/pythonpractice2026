# %% [markdown]
# Keywords
#
# python is a case sensitive language

# %% [markdown]
# In a programming, a keyword is a word that is reserved by a program because the word has a special meaning. Keywords can be commands or parameters. Every programming language has a set of keywords that cannot be used as variable names

# %%
# python has 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### Identifier

# %% [markdown]
# A python identifier is a name used to identify a variable,
# function, class, module or other object.

# %% [markdown]
# ### Rules for setting identifiers

# %% [markdown]
# Can only start with an alphabet or
#
# Followed by 0 or more letter, _ and digits
#
# Kwywords cannot be used as an identifier

# %%
_ = "Yash"
print(_)
# Out:
# Yash

# %%
num1 = "Yash"
print(num1)
# Out:
# Yash
