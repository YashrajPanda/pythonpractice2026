# %%
# c lang
# int a

# %%
name = "Yashraj"
print(name)
# Out:
# Yashraj

# %%
# no variable declaration is required in python. We can directly assign a value to a variable and start using it.

# %%
# Dynamic Typing
a = 10
print(a)
# Out:
# 10

# %%
# Ststic Typing
a = "Yashraj"
print(a)
# Out:
# Yashraj

# %%
# Dynamic binding
# Ststic binding

# %%
# special syntax
a = 2; b = 3; c = 4
# print(a)
# print(b)
# print(c)
print(a, b, c)
# Out:
# 2 3 4

# %%
a, b, c = 2, 3, 4
print(a, b, c)
# Out:
# 2 3 4
