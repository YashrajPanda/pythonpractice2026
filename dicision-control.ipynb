# %% [markdown]
# Correct email : AgentX@gmail.com
#
# password : 1234

# %%
email = input("Apna email bata : ")
password = input("Apna password bata : ")

if "@" in email:
    if email == "AgentX@gmail.com" and password == "1234":
        print("Login successful! Welcome, Agent X.")
    elif email == "AgentX@gmail.com" and password != "1234":
        print("Incorrect password. Please try again.")
        password = input("Password fir se bata : ")
        if password == "1234":
            print("Finally correct! Welcome, Agent X.")
        else:
            print("Still incorrect. Access denied.")
    else:
        print("Email not recognized. Please check your email and try again.")
else:
    print("Invalid email format. Please include '@' in your email.")
# Out:
# Invalid email format. Please include '@' in your email.
